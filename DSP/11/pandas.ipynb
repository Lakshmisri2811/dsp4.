# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("bollywood.csv")
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2    04-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4    04-Jan-13             Rajdhani Express           N     Drama
# 4       5    04-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2    04-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4    04-Jan-13    Rajdhani Express           N     Drama        7
# 4     5    04-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
df.tail()
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 144      15                30.00       3250917          8185              615
# 145      13                32.10       5592977         15464             1513
# 146      32                12.00       2316047          4289              807
# 147       5                11.89       4674795          3706              762
# 148     150               120.00       4740727         13466             2649

# %%
a=df.head()

# %%
print(a)
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2    04-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4    04-Jan-13    Rajdhani Express           N     Drama        7
# 4     5    04-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
a.index(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 a.index(2)
#
# TypeError: 'RangeIndex' object is not callable

# %%
a.index[0,3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 a.index[0,3]
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py:942, in RangeIndex.__getitem__(self, key)
#     935     raise IndexError(
#     936         "only integers, slices (`:`), "
#     937         "ellipsis (`...`), numpy.newaxis (`None`) "
#     938         "and integer or boolean "
#     939         "arrays are valid indices"
#     940     )
#     941 # fall back to Int64Index
# --> 942 return super().__getitem__(key)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5055, in Index.__getitem__(self, key)
#    5048 if com.is_bool_indexer(key):
#    5049     # if we have list[bools, length=1e5] then doing this check+convert
#    5050     #  takes 166 µs + 2.1 ms and cuts the ndarray.__getitem__
#    5051     #  time below from 3.8 ms to 496 µs
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 5 non-null      int64
#  1   Release Date         5 non-null      object
#  2   MovieName            5 non-null      object
#  3   ReleaseTime          5 non-null      object
#  4   Genre                5 non-null      object
#  5   Budget               5 non-null      int64
#  6   BoxOfficeCollection  5 non-null      float64
#  7   YoutubeViews         5 non-null      int64
#  8   YoutubeLikes         5 non-null      int64
#  9   YoutubeDislikes      5 non-null      int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 528.0+ bytes

# %%
a.describe()
# Out:
#            SlNo     Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# count  5.000000   5.000000              5.00000  5.000000e+00      5.000000
# mean   3.000000  16.200000             26.23000  2.678414e+06   6587.000000
# std    1.581139  11.798305             43.73985  3.496053e+06  11333.265372
# min    1.000000   7.000000              0.35000  4.262600e+04     86.000000
# 25%    2.000000  10.000000              4.00000  5.723360e+05    586.000000
# 50%    3.000000  10.000000             10.80000  1.087320e+06   1129.000000
# 75%    4.000000  18.000000             12.00000  3.113427e+06   4512.000000
# max    5.000000  36.000000            104.00000  8.576361e+06  26622.000000
#
#        YoutubeDislikes
# count         5.000000
# mean        792.200000
# std        1091.792883
# min          19.000000
# 25%          54.000000
# 50%         137.000000
# 75%        1224.000000
# max        2527.000000

# %%
df.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews  \
# count  149.000000  149.000000           149.000000  1.490000e+02
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
df.mode()
# Out:
#      SlNo Release Date                  MovieName ReleaseTime   Genre  Budget  \
# 0       1    09-May-14                   2 States           N  Comedy    10.0
# 1       2          NaN                         3G         NaN     NaN     NaN
# 2       3          NaN  ABCD _ Any Body Can Dance         NaN     NaN     NaN
# 3       4          NaN                 Aashiqui 2         NaN     NaN     NaN
# 4       5          NaN                      Aatma         NaN     NaN     NaN
# ..    ...          ...                        ...         ...     ...     ...
# 144   145          NaN    Yeh Jawaani Hai Deewani         NaN     NaN     NaN
# 145   146          NaN                Youngistaan         NaN     NaN     NaN
# 146   147          NaN                    Zanjeer         NaN     NaN     NaN
# 147   148          NaN                        Zid         NaN     NaN     NaN
# 148   149          NaN            Zilla Ghaziabad         NaN     NaN     NaN
#
# ...

# %%
df.index[2]
# Out:
# 2

# %%
df.loc[2]
# Out:
# SlNo                                    3
# Release Date                    18-Jul-14
# MovieName              Amit Sahni Ki List
# ReleaseTime                             N
# Genre                              Comedy
# Budget                                 10
# BoxOfficeCollection                   4.0
# YoutubeViews                       572336
# YoutubeLikes                          586
# YoutubeDislikes                        54
# Name: 2, dtype: object

# %%
df.columns
# Out:
# Index(['SlNo', 'Release Date', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes'],
#       dtype='object')

# %%
df.rows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df.rows()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'
